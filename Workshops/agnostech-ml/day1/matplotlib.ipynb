# %%
from matplotlib import pyplot as plt

# %%
import numpy as n

# %%
x = n.random.random(5)
y = n.random.random(5)

# %%
plt.scatter(x,y, color='blue')
plt.show()

# %%
plt.plot(x,y, color='green')
plt.show()

# %%
plt.bar(x,y, color='red')
plt.show()

# %%
a = n.random.random(10)
b = n.random.random(10)
plt.scatter(x,y, color='blue')
plt.scatter(a,b, color='red')
plt.show()

# %%
a = n.random.random(10)
b = n.random.random(10)
plt.scatter(x,y, color='blue')
plt.scatter(a,b, color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.scatter(x,y, color='blue', label='1')
plt.scatter(a,b, color='red', label='2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
plt.scatter(x,y, color='blue', label='1')
plt.scatter(a,b, color='red', label='2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper left')
plt.show()

# %%
s = n.random.randint(0, 180, 50)
s.sort()
s
# Out:
# array([ 12,  13,  14,  18,  20,  25,  27,  27,  44,  47,  48,  49,  52,
#         53,  53,  54,  58,  61,  72,  72,  73,  80,  85,  89,  91,  92,
#        104, 110, 113, 114, 114, 116, 120, 130, 132, 135, 136, 138, 144,
#        145, 148, 150, 151, 154, 157, 160, 165, 170, 172, 173])

# %%
v = n.sin(s*n.pi/180)

# %%
plt.plot(s,v, color='green')
plt.show()

# %%
t = n.random.randint(0, 360, 50)
t.sort()
sin = n.sin(s*n.pi/180)
cos = n.con(s*n.pi/180)
tan = n.tan(s*n.pi/180)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-02624a5507f2> in <module>
#       2 t.sort()
#       3 sin = n.sin(s*n.pi/180)
# ----> 4 cos = n.con(s*n.pi/180)
#       5 tan = n.tan(s*n.pi/180)
#
# AttributeError: module 'numpy' has no attribute 'con'

# %%
cos = n.cos(s*n.pi/180)
tan = n.tan(s*n.pi/180)

# %%
plt.plot(t,sin, color='green', label='sin')
plt.plot(t,cos, color='blue' , label='cos')
plt.plot(t,tan, color='red'  , label='tan')
plt.show()

# %%
plt.plot(t,sin, color='green', label='sin')
plt.plot(t,cos, color='blue' , label='cos')
plt.show()

# %%
sin = n.sin(t*n.pi/180)
cos = n.con(t*n.pi/180)
tan = n.tan(t*n.pi/180)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-7802d366cbfc> in <module>
#       1 sin = n.sin(t*n.pi/180)
# ----> 2 cos = n.con(t*n.pi/180)
#       3 tan = n.tan(t*n.pi/180)
#
# AttributeError: module 'numpy' has no attribute 'con'

# %%
sin = n.sin(s*n.pi/180)
cos = n.cos(s*n.pi/180)
tan = n.tan(s*n.pi/180)

# %%
plt.plot(t,sin, color='green', label='sin')
plt.plot(t,cos, color='blue' , label='cos')
plt.plot(t,tan, color='red'  , label='tan')
plt.show()

# %%
sin = n.sin(t*n.pi/180)
cos = n.cos(t*n.pi/180)
tan = n.tan(t*n.pi/180)

# %%
plt.plot(t,sin, color='green', label='sin')
plt.plot(t,cos, color='blue' , label='cos')
plt.plot(t,tan, color='red'  , label='tan')
plt.legend()
plt.show()

# %%
plt.plot(t,sin, color='green', label='sin')
plt.plot(t,cos, color='blue' , label='cos')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,9), dpi=50)
plt.plot(t,sin, color='green', label='sin')
plt.plot(t,cos, color='blue' , label='cos')
plt.legend()
plt.show()
